# %% [markdown]
# <a href="https://colab.research.google.com/github/Cristian-Rojas2/TalentoTech/blob/main/Taller.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df_1 = pd.read_excel("/content/example_ventas.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-562e63f34280> in <cell line: 1>()
# ----> 1 df_1 = pd.read_excel("/content/example_ventas.xlsx")
#
# NameError: name 'pd' is not defined

# %%
df_1
# Out:
#                   Fecha   Region      Producto Vendedor  Ventas
# 0   2024-02-16 00:00:00    Oeste      Sistemas    Kevin   32855
# 1   2024-02-05 00:00:00  Central      Sistemas    Karen   30633
# 2   2024-02-17 00:00:00    Oeste      Sistemas     Sara   23151
# 3   2024-02-04 00:00:00  Central      Sistemas    David   20098
# 4   2024-02-10 00:00:00     Este      Sistemas      Ana   13531
# 5   2024-02-11 00:00:00     Este      Sistemas    Lucas   13374
# 6   2024-02-03 00:00:00  Central  Dispositivos    Karen   12948
# 7   2024-02-02 00:00:00  Central  Dispositivos    David   11420
# 8   2024-02-14 00:00:00    Oeste  Dispositivos    Kevin   10711
# 9   2024-02-08 00:00:00     Este  Dispositivos      Ana   10348
# 10  2024-02-06 00:00:00     Este    Accesorios      Ana    9323
# 11  2024-02-09 00:00:00     Este  Dispositivos    Lucas    9312
# 12  2024-02-15 00:00:00    Oeste  Dispositivos     Sara    8780
# 13  2024-01-31 00:00:00  Central    Accesorios    David    8287
# ...

# %%
df_2 = pd.read_excel("/content/Ventas.xlsx")

# %%
df_2
# Out:
#         Fecha   Region      Producto Vendedor  Ventas
# 0  2024-02-16    Oeste      Sistemas    Kevin   32855
# 1  2024-02-05  Central      Sistemas    Karen   30633
# 2  2024-02-17    Oeste      Sistemas     Sara   23151
# 3  2024-02-04  Central      Sistemas    David   20098
# 4  2024-02-10     Este      Sistemas      Ana   13531
# 5  2024-02-11     Este      Sistemas    Lucas   13374
# 6  2024-02-03  Central  Dispositivos    Karen   12948
# 7  2024-02-02  Central  Dispositivos    David   11420
# 8  2024-02-14    Oeste  Dispositivos    Kevin   10711
# 9  2024-02-08     Este  Dispositivos      Ana   10348
# 10 2024-02-06     Este    Accesorios      Ana    9323
# 11 2024-02-09     Este  Dispositivos    Lucas    9312
# 12 2024-02-15    Oeste  Dispositivos     Sara    8780
# 13 2024-01-31  Central    Accesorios    David    8287
# 14 2024-02-07     Este    Accesorios    Lucas    7667
# 15 2024-02-01  Central    Accesorios    Karen    6909
# ...

# %%
#Ejercicio 1: Mostrar las primeras filas del Dataframe
print("Ejercicio 1: Mostrar las primeras filas del Dataframe")
print(df_2.head(5))
# Out:
# Ejercicio 1: Mostrar las primeras filas del Dataframe
#        Fecha   Region  Producto Vendedor  Ventas
# 0 2024-02-16    Oeste  Sistemas    Kevin   32855
# 1 2024-02-05  Central  Sistemas    Karen   30633
# 2 2024-02-17    Oeste  Sistemas     Sara   23151
# 3 2024-02-04  Central  Sistemas    David   20098
# 4 2024-02-10     Este  Sistemas      Ana   13531

# %%
#Ejercicio 2: Calcular el total de ventas por región
print("Ejercicio 2: Calcular el total de ventas por región")
ventas_por_region = df_2.groupby('Region')['Ventas'].sum()
print(ventas_por_region)
print("\n")
print(df_2.head(10))
# Out:
# Ejercicio 2: Calcular el total de ventas por región
# Region
# Central    90295
# Este       63555
# Oeste      85683
# Name: Ventas, dtype: int64
#
#
#        Fecha   Region      Producto Vendedor  Ventas
# 0 2024-02-16    Oeste      Sistemas    Kevin   32855
# 1 2024-02-05  Central      Sistemas    Karen   30633
# 2 2024-02-17    Oeste      Sistemas     Sara   23151
# 3 2024-02-04  Central      Sistemas    David   20098
# 4 2024-02-10     Este      Sistemas      Ana   13531
# 5 2024-02-11     Este      Sistemas    Lucas   13374
# 6 2024-02-03  Central  Dispositivos    Karen   12948
# 7 2024-02-02  Central  Dispositivos    David   11420
# 8 2024-02-14    Oeste  Dispositivos    Kevin   10711
# 9 2024-02-08     Este  Dispositivos      Ana   10348

# %%
#Ejercicio 3: Filtrar el Dataframe para mostrar solo las ventas realizadas por David
print("Ejercicio 3: Filtrar el Dataframe para mostrar solo las ventas realizadas por David")
ventas_david = df_2[df_2['Vendedor'] ==  'David']
print(ventas_david)
# Out:
# Ejercicio 3: Filtrar el Dataframe para mostrar solo las ventas realizadas por David
#         Fecha   Region      Producto Vendedor  Ventas
# 3  2024-02-04  Central      Sistemas    David   20098
# 7  2024-02-02  Central  Dispositivos    David   11420
# 13 2024-01-31  Central    Accesorios    David    8287

# %%
#Ejercicio 4: Calcular el promedio de ventas por region
print("Ejercicio 4: Calcular el promedio de ventas por region")
ventas_por_producto = df_2.groupby('Region')['Ventas'].mean()
print(ventas_por_producto)
# Out:
# Ejercicio 4: Calcular el promedio de ventas por region
# Region
# Central    15049.166667
# Este       10592.500000
# Oeste      14280.500000
# Name: Ventas, dtype: float64

# %%
#Ejercicio 5: Calcular el promedio de ventas por región con dos decimales
print("Ejercicio 5: Calcular el promedio de ventas por región con dos decimales")
ventas_por_producto1 = df_2.groupby('Region')['Ventas'].mean().round(2)
print(ventas_por_producto1)
# Out:
# Ejercicio 5: Calcular el promedio de ventas por región con dos decimales
# Region
# Central    15049.17
# Este       10592.50
# Oeste      14280.50
# Name: Ventas, dtype: float64

# %%
#Ejercicio 6: Ordenar el Dataframe por ventas en orden descendente
print("Ejercicio 6: Ordenar el Dataframe por ventas en orden descendente")
df_ordenado = df_2.sort_values(by='Ventas', ascending=False)
print(df_ordenado)
# Out:
# Ejercicio 6: Ordenar el Dataframe por ventas en orden descendente
#         Fecha   Region      Producto Vendedor  Ventas
# 0  2024-02-16    Oeste      Sistemas    Kevin   32855
# 1  2024-02-05  Central      Sistemas    Karen   30633
# 2  2024-02-17    Oeste      Sistemas     Sara   23151
# 3  2024-02-04  Central      Sistemas    David   20098
# 4  2024-02-10     Este      Sistemas      Ana   13531
# 5  2024-02-11     Este      Sistemas    Lucas   13374
# 6  2024-02-03  Central  Dispositivos    Karen   12948
# 7  2024-02-02  Central  Dispositivos    David   11420
# 8  2024-02-14    Oeste  Dispositivos    Kevin   10711
# 9  2024-02-08     Este  Dispositivos      Ana   10348
# 10 2024-02-06     Este    Accesorios      Ana    9323
# 11 2024-02-09     Este  Dispositivos    Lucas    9312
# 12 2024-02-15    Oeste  Dispositivos     Sara    8780
# 13 2024-01-31  Central    Accesorios    David    8287
# 14 2024-02-07     Este    Accesorios    Lucas    7667
# ...

# %%
#Ejercicio 7: Filtrar las filas con ventas mayores a 10000 y ordenar de mayor a menor
print("Ejercicio 7: Filtrar las filas con ventas mayores a 10000 y ordenar de mayor a menor")
df_filtrado = df_2[df_2['Ventas'] > 10000].sort_values(by='Ventas', ascending=False)
print(df_filtrado)
print("\n")
# Out:
# Ejercicio 7: Filtrar las filas con ventas mayores a 10000 y ordenar de mayor a menor
#        Fecha   Region      Producto Vendedor  Ventas
# 0 2024-02-16    Oeste      Sistemas    Kevin   32855
# 1 2024-02-05  Central      Sistemas    Karen   30633
# 2 2024-02-17    Oeste      Sistemas     Sara   23151
# 3 2024-02-04  Central      Sistemas    David   20098
# 4 2024-02-10     Este      Sistemas      Ana   13531
# 5 2024-02-11     Este      Sistemas    Lucas   13374
# 6 2024-02-03  Central  Dispositivos    Karen   12948
# 7 2024-02-02  Central  Dispositivos    David   11420
# 8 2024-02-14    Oeste  Dispositivos    Kevin   10711
# 9 2024-02-08     Este  Dispositivos      Ana   10348

# %%
#Ejercicio 8: Eliminar la columna "Vendedor"
print("Ejercicio 8: Eliminar la columna Vendedor")
df_sin_vendedor = df_2.drop(columns=['Vendedor'])
print(df_sin_vendedor)
print("\n")
# Out:
# Ejercicio 8: Eliminar la columna Vendedor
#         Fecha   Region      Producto  Ventas
# 0  2024-02-16    Oeste      Sistemas   32855
# 1  2024-02-05  Central      Sistemas   30633
# 2  2024-02-17    Oeste      Sistemas   23151
# 3  2024-02-04  Central      Sistemas   20098
# 4  2024-02-10     Este      Sistemas   13531
# 5  2024-02-11     Este      Sistemas   13374
# 6  2024-02-03  Central  Dispositivos   12948
# 7  2024-02-02  Central  Dispositivos   11420
# 8  2024-02-14    Oeste  Dispositivos   10711
# 9  2024-02-08     Este  Dispositivos   10348
# 10 2024-02-06     Este    Accesorios    9323
# 11 2024-02-09     Este  Dispositivos    9312
# 12 2024-02-15    Oeste  Dispositivos    8780
# 13 2024-01-31  Central    Accesorios    8287
# 14 2024-02-07     Este    Accesorios    7667
# 15 2024-02-01  Central    Accesorios    6909
# 16 2024-02-13    Oeste    Accesorios    5442
# 17 2024-02-12    Oeste    Accesorios    4744

# %%
df_2['Fecha'] = pd.to_datetime(df_2['Fecha']).dt.strftime('%d-%m-%Y')
df_2
# Out:
#          Fecha   Region      Producto Vendedor  Ventas
# 0   16-02-2024    Oeste      Sistemas    Kevin   32855
# 1   05-02-2024  Central      Sistemas    Karen   30633
# 2   17-02-2024    Oeste      Sistemas     Sara   23151
# 3   04-02-2024  Central      Sistemas    David   20098
# 4   10-02-2024     Este      Sistemas      Ana   13531
# 5   11-02-2024     Este      Sistemas    Lucas   13374
# 6   03-02-2024  Central  Dispositivos    Karen   12948
# 7   02-02-2024  Central  Dispositivos    David   11420
# 8   14-02-2024    Oeste  Dispositivos    Kevin   10711
# 9   08-02-2024     Este  Dispositivos      Ana   10348
# 10  06-02-2024     Este    Accesorios      Ana    9323
# 11  09-02-2024     Este  Dispositivos    Lucas    9312
# 12  15-02-2024    Oeste  Dispositivos     Sara    8780
# 13  31-01-2024  Central    Accesorios    David    8287
# 14  07-02-2024     Este    Accesorios    Lucas    7667
# 15  01-02-2024  Central    Accesorios    Karen    6909
# ...

# %%
import pandas as pd
df_2.rename(columns={' Fecha': 'Fecha'}, inplace=True)

df_2['Fecha'] = df_2['Fecha'].str.replace('/', '-')

print(df_2)
# Out:
#          Fecha   Region      Producto Vendedor  Ventas
# 0   16-02-2024    Oeste      Sistemas    Kevin   32855
# 1   05-02-2024  Central      Sistemas    Karen   30633
# 2   17-02-2024    Oeste      Sistemas     Sara   23151
# 3   04-02-2024  Central      Sistemas    David   20098
# 4   10-02-2024     Este      Sistemas      Ana   13531
# 5   11-02-2024     Este      Sistemas    Lucas   13374
# 6   03-02-2024  Central  Dispositivos    Karen   12948
# 7   02-02-2024  Central  Dispositivos    David   11420
# 8   14-02-2024    Oeste  Dispositivos    Kevin   10711
# 9   08-02-2024     Este  Dispositivos      Ana   10348
# 10  06-02-2024     Este    Accesorios      Ana    9323
# 11  09-02-2024     Este  Dispositivos    Lucas    9312
# 12  15-02-2024    Oeste  Dispositivos     Sara    8780
# 13  31-01-2024  Central    Accesorios    David    8287
# 14  07-02-2024     Este    Accesorios    Lucas    7667
# 15  01-02-2024  Central    Accesorios    Karen    6909
# ...
